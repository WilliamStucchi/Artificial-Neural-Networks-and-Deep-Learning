# %% [markdown]
# # Description of the notebook

# %% [markdown]
# Students:
# - Teka Kimbi Ntimanputu (10673197)
# - William Stucchi (10661711)
# - Lorenzo Veronese (10654901)

# %% [markdown]
# This notebook is one of the experiments described in Section III of the report. The resulting model reached a performance of 0.0068 MSE on the phase 1 remote dataset.
#
# This notebook also contains the code initially implemented to perform data augmentation: since this technique was not successful, it has been discarded in the subsequent steps.

# %% [markdown]
# # Libraries

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.15.0

# %%
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
plt.rc('font', size=16)
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Import data

# %% [markdown]
# Google Drive:

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/My Drive/Colab Notebooks/ANNDL/Challenge2
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/ANNDL/Challenge2

# %% [markdown]
# Open the zip file containing the dataset (Note: this is without padding):

# %%
import zipfile

# Replace 'your_file.zip' with the actual name of your zip file
zip_file_name = 'training_dataset_preprocessed.zip'

# Read the zip file
with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    # Extract all the contents to a folder (you can change the destination folder)
    zip_ref.extractall('/content/dataset')

# %%
import numpy as np

categories = np.load('/content/dataset/categories.npy', allow_pickle=True)
print(categories)
# Out:
# ['D' 'D' 'D' ... 'F' 'F' 'F']

# %%
training_data = np.load('/content/dataset/training_dataset_no_padding.npy', allow_pickle=True)
print(training_data)
# Out:
# [array([0.49166667, 0.5240741 , 0.54444444, 0.46388888, 0.40648147,
#         0.35462964, 0.31296295, 0.36666667, 0.38333333, 0.27962962,
#         0.23796296, 0.2574074 , 0.47962964, 0.4324074 , 0.53518516,
#         0.48055556, 0.37592593, 0.3861111 , 0.32685184, 0.36666667,
#         0.25555557, 0.23981482, 0.21111111, 0.26481482, 0.46851853,
#         0.46944445, 0.41666666, 0.4398148 , 0.3611111 , 0.32592592,
#         0.3074074 , 0.3425926 , 0.28611112, 0.2787037 , 0.18425927,
#         0.21111111, 0.38518518, 0.375     , 0.44444445, 0.32962963,
#         0.38981482, 0.29444444, 0.27037036, 0.3351852 , 0.31666666,
#         0.3148148 , 0.2888889 , 0.31203705, 0.39444444, 0.475     ,
#         0.51666665, 0.47685185, 0.47777778, 0.37222221, 0.32685184,
#         0.43888888, 0.35833332, 0.40648147, 0.36944443, 0.38981482,
#         0.5546296 , 0.53333336, 0.5537037 , 0.53518516, 0.48333332,
#         0.5046296 , 0.42777777, 0.4787037 , 0.46666667, 0.42962962,
#         0.43888888, 0.41296297, 0.55833334, 0.5231481 , 0.5694444 ,
#         0.5638889 , 0.5148148 , 0.5083333 , 0.45185184, 0.6101852 ,
#         0.60462964, 0.5972222 , 0.5796296 , 0.5416667 , 0.6175926 ,
#         0.6537037 , 0.60925925, 0.5555556 , 0.5101852 , 0.45555556,
#         0.4138889 , 0.5175926 , 0.43333334, 0.41111112, 0.38425925,
#         0.42314816, 0.43888888, 0.48703703, 0.4722222 , 0.5       ,
#         0.44351852, 0.3712963 , 0.36666667, 0.39537036, 0.34444445,
#         0.3351852 , 0.3       , 0.30462962, 0.37407407, 0.43703705,
#         0.41759259, 0.39537036, 0.3787037 , 0.28055555, 0.3101852 ,
#         0.30555555, 0.32592592, 0.34907407, 0.25925925, 0.28703704,
#         0.8414634 , 0.652439  , 0.7865854 , 0.8231707 , 0.6859756 ,
#         0.60365856, 0.56707317, 0.63414633, 0.73170733, 0.78963417,
#         0.79268295, 0.7042683 , 0.6890244 , 0.6707317 , 0.6981707 ,
#         0.6554878 , 0.60365856, 0.5640244 , 0.5731707 , 0.5731707 ,
#         0.5792683 , 0.55487806, 0.47256097, 0.5335366 , 0.5518293 ,
#         0.57012194, 0.69512194, 0.6768293 , 0.5335366 , 0.5152439 ,
#         0.50914633, 0.5       , 0.5335366 , 0.5518293 , 0.5762195 ,
#         0.5762195 , 0.5884146 , 0.54268295, 0.6097561 , 0.5914634 ],
#        dtype=float32)                                               ]

# %%
valid_periods = np.load('/content/dataset/valid_periods.npy', allow_pickle=True)
print(valid_periods)
# Out:
# [[2325 2776]
#  [2325 2776]
#  [2325 2776]
#  ...
#  [2676 2776]
#  [2676 2776]
#  [2676 2776]]

# %% [markdown]
# # Explore data

# %% [markdown]
# Plot the time series and print some characteristics of the data:

# %%
print(type(categories))
categories_names, counts = np.unique(categories, return_counts=True)
for letter, count in zip(categories_names, counts):
    print(f"Letter {letter}: {count} occurrences")
# Out:
# <class 'numpy.ndarray'>
# Letter A: 5728 occurrences
# Letter B: 10987 occurrences
# Letter C: 10017 occurrences
# Letter D: 10016 occurrences
# Letter E: 10975 occurrences
# Letter F: 277 occurrences

# %%
print("categories: ", len(categories))
print("training_data: ", len(training_data))
print("valid_periods: ", len(valid_periods))
# Out:
# categories:  48000
# training_data:  48000
# valid_periods:  48000

# %%
import matplotlib.pyplot as plt

stop = 0
for i, (data, category) in enumerate(zip(training_data, categories)):
    if(category == 'A'):
        plt.figure(figsize=(50, 15))
        plt.plot(training_data[i], label='Time Series Data')
        plt.title('Time Series Plot')
        plt.xlabel('Index')
        plt.ylabel('Data Values')
        plt.legend()
        plt.show()

        stop += 1
        if(stop==1): break

# %%
import matplotlib.pyplot as plt

stop = 0
for i, (data, category) in enumerate(zip(training_data, categories)):
    if(category == 'B'):
        plt.figure(figsize=(50, 15))
        plt.plot(training_data[i], label='Time Series Data')
        plt.title('Time Series Plot')
        plt.xlabel('Index')
        plt.ylabel('Data Values')
        plt.legend()
        plt.show()

        stop += 1
        if(stop==1): break

# %%
import matplotlib.pyplot as plt

stop = 0
for i, (data, category) in enumerate(zip(training_data, categories)):
    if(category == 'C'):
        plt.figure(figsize=(50, 15))
        plt.plot(training_data[i], label='Time Series Data')
        plt.title('Time Series Plot')
        plt.xlabel('Index')
        plt.ylabel('Data Values')
        plt.legend()
        plt.show()

        stop += 1
        if(stop==1): break

# %%
import matplotlib.pyplot as plt

stop = 0
for i, (data, category) in enumerate(zip(training_data, categories)):
    if(category == 'D'):
        plt.figure(figsize=(50, 15))
        plt.plot(training_data[i], label='Time Series Data')
        plt.title('Time Series Plot')
        plt.xlabel('Index')
        plt.ylabel('Data Values')
        plt.legend()
        plt.show()

        stop += 1
        if(stop==1): break

# %%
import matplotlib.pyplot as plt

stop = 0
for i, (data, category) in enumerate(zip(training_data, categories)):
    if(category == 'E'):
        plt.figure(figsize=(50, 15))
        plt.plot(training_data[i], label='Time Series Data')
        plt.title('Time Series Plot')
        plt.xlabel('Index')
        plt.ylabel('Data Values')
        plt.legend()
        plt.show()

        stop += 1
        if(stop==1): break

# %%
import matplotlib.pyplot as plt

stop = 0
for i, (data, category) in enumerate(zip(training_data, categories)):
    if(category == 'F'):
        plt.figure(figsize=(50, 15))
        plt.plot(training_data[i], label='Time Series Data')
        plt.title('Time Series Plot')
        plt.xlabel('Index')
        plt.ylabel('Data Values')
        plt.legend()
        plt.show()

        stop += 1
        if(stop==1): break

# %% [markdown]
# # Training-validation split

# %% [markdown]
# Create data structures useful for the subsequent steps and create a version of the dataset where all time series of each category are separated from the others:

# %%
categories_names, counts = np.unique(categories, return_counts=True)
dataset_by_categories = [[], [], [], [], [], []]
index_to_category = {
    0 : 'A',
    1 : 'B',
    2 : 'C',
    3 : 'D',
    4 : 'E',
    5 : 'F'
}
category_to_index = {
    'A' : 0,
    'B' : 1,
    'C' : 2,
    'D' : 3,
    'E' : 4,
    'F' : 5
}


for i, (data, category) in enumerate(zip(training_data, categories)):
    dataset_by_categories[category_to_index[category]].append(data)

dataset_by_categories = np.array(dataset_by_categories)
dataset_by_categories[0][0]
# Out:
# array([0.3560538 , 0.25650224, 0.29596412, 0.26816145, 0.20896861,
#        0.29506725, 0.30403587, 0.25650224, 0.2852018 , 0.23049328,
#        0.21883409, 0.21704036, 0.21255605, 0.2116592 , 0.22511211,
#        0.1632287 , 0.1748879 , 0.14439462, 0.22690582, 0.18565023,
#        0.12376682, 0.18744394, 0.17757848, 0.19910313, 0.18475336,
#        0.22600897, 0.22242153, 0.17937219, 0.13363229, 0.18923767,
#        0.19730942, 0.19013453, 0.16860987, 0.15336323, 0.12825112,
#        0.11748879, 0.17399102, 0.14439462, 0.13721973, 0.15784754,
#        0.12107623, 0.13452914, 0.09686099, 0.09686099, 0.11210762,
#        0.08878924, 0.1147982 , 0.12735426, 0.15336323, 0.14170404,
#        0.12556054, 0.1264574 , 0.05829597, 0.09686099, 0.15336323,
#        0.0690583 , 0.10224215, 0.11659193, 0.09596413, 0.13901345,
#        0.1219731 , 0.06098655, 0.08251121, 0.03766816, 0.04753363,
#        0.01524664, 0.07802691, 0.05560538, 0.07713004, 0.06098655,
#        0.06188341, 0.0573991 , 0.02959641, 0.0573991 , 0.04932735,
#        0.1147982 , 0.0690583 , 0.09506726, 0.05650224, 0.        ,
#        0.04484305, 0.02600897, 0.02959641, 0.05919283, 0.08789238,
#        0.07533632, 0.1309417 , 0.1309417 , 0.11210762, 0.08161435,
#        0.09596413, 0.12017937, 0.0735426 , 0.1147982 , 0.11210762,
#        0.13004485, 0.11210762, 0.15426008, 0.11390135, 0.10493273,
#        0.18923767, 0.12466368, 0.18116592, 0.15695067, 0.16950673,
#        0.13991031, 0.1632287 , 0.17937219, 0.2206278 , 0.22152467,
#        0.24304932, 0.20986547, 0.2502242 , 0.24663678, 0.23946188,
#        0.2690583 , 0.16591929, 0.23228699, 0.2278027 , 0.20627803,
#        0.20538117, 0.25201795, 0.27892378, 0.25919282, 0.24484305,
#        0.24663678, 0.26995516, 0.296861  , 0.18744394, 0.20269059,
#        0.16950673, 0.21434978, 0.27982062, 0.2529148 , 0.24843049,
#        0.17040358, 0.16950673, 0.24484305, 0.26547086, 0.16233183,
#        0.1426009 , 0.16950673, 0.18026906, 0.22242153, 0.17309417,
#        0.16412556, 0.22242153, 0.15964125, 0.10762332, 0.24932736,
#        0.20179372, 0.21973094, 0.10941704, 0.1147982 , 0.1309417 ,
#        0.06367713, 0.21434978, 0.15426008, 0.15964125, 0.17578475,
#        0.14798206, 0.17757848, 0.1470852 , 0.16950673, 0.06547085,
#        0.10493273, 0.1309417 , 0.14349777, 0.2367713 , 0.17309417,
#        0.17757848, 0.18744394, 0.17668161, 0.19461884, 0.23139013,
#        0.15964125, 0.2367713 , 0.25201795, 0.3632287 , 0.39372197,
#        0.47623318, 0.4735426 , 0.432287  , 0.48161435, 0.5282511 ,
#        0.529148  , 0.53183854, 0.49775785, 0.45112106, 0.54260087,
#        0.5901345 , 0.6511211 , 0.7730942 , 0.8977578 , 0.70941705,
#        0.89147985, 0.7892377 , 0.90044844, 0.8807175 , 0.8134529 ,
#        0.9022421 , 0.9112108 , 0.967713  , 1.        , 0.7085202 ,
#        0.73273546, 0.6439462 , 0.70493275, 0.55515695, 0.6986547 ,
#        0.8215247 , 0.6941704 , 0.7479821 , 0.68520176, 0.8008969 ,
#        0.66547084, 0.767713  , 0.7201794 , 0.593722  , 0.68609864,
#        0.56233186, 0.5542601 , 0.5820628 , 0.5748879 , 0.5372197 ,
#        0.5470852 , 0.6959641 , 0.77578473, 0.53901345, 0.61165917,
#        0.5381166 , 0.56681615, 0.5174888 , 0.73901343, 0.7040359 ,
#        0.59461886, 0.5820628 , 0.5488789 , 0.5013453 , 0.64035875],
#       dtype=float32)

# %% [markdown]
# Shuffle the the time series contained inside each category list:

# %%
np.random.seed(42)
for category in dataset_by_categories:
    np.random.shuffle(category)
dataset_by_categories[0][0]
# Out:
# array([0.09083416, 0.11135604, 0.11138821, 0.09512629, 0.08606377,
#        0.07637145, 0.07420266, 0.0756048 , 0.09573994, 0.08537591,
#        0.07476568, 0.04915958, 0.06078921, 0.08370345, 0.07865696,
#        0.07128735, 0.06438264, 0.0576733 , 0.05626497, 0.07262265,
#        0.06024503, 0.05874837, 0.05553907, 0.04201939, 0.04707289,
#        0.05678718, 0.03323365, 0.0280992 , 0.03061388, 0.0334106 ,
#        0.01862821, 0.03345053, 0.02059251, 0.03819083, 0.02437792,
#        0.        , 0.00745116, 0.01712146, 0.01622909, 0.00408256,
#        0.0217185 , 0.01059223, 0.04549293, 0.05330395, 0.02902577,
#        0.03558172, 0.03650588, 0.02626428, 0.03722911, 0.05024905,
#        0.00864775, 0.0173225 , 0.04477011, 0.04620855, 0.03100943,
#        0.04506579, 0.03359981, 0.02668526, 0.01542394, 0.00135165,
#        0.01480574, 0.00576223, 0.00470582, 0.03176446, 0.03020446,
#        0.02699236, 0.01540042, 0.03301539, 0.02092402, 0.01173632,
#        0.03720886, 0.02868418, 0.05255431, 0.03497124, 0.02287903,
#        0.0352863 , 0.03893656, 0.03282722, 0.01470187, 0.05040263,
#        0.05715746, 0.06573066, 0.06604195, 0.08395712, 0.10064027,
#        0.11525389, 0.09650194, 0.13291197, 0.14118415, 0.1424402 ,
#        0.16074382, 0.16062859, 0.13397676, 0.15238713, 0.16824833,
#        0.12616459, 0.14106648, 0.1722245 , 0.15691048, 0.15506601,
#        0.15633862, 0.1543737 , 0.14270312, 0.15681306, 0.1729743 ,
#        0.14535989, 0.15708166, 0.12448277, 0.15877335, 0.1786365 ,
#        0.14772698, 0.17845029, 0.1787153 , 0.18529904, 0.18917848,
#        0.18401045, 0.18262573, 0.19643213, 0.21466047, 0.19239253,
#        0.18921596, 0.21154046, 0.22925991, 0.23906316, 0.23253287,
#        0.24131882, 0.2321891 , 0.25096166, 0.27036327, 0.2764028 ,
#        0.28591722, 0.24438557, 0.27556098, 0.2751748 , 0.29735833,
#        0.30598888, 0.30817208, 0.29092482, 0.32094103, 0.33224997,
#        0.32626972, 0.36037943, 0.36321098, 0.34107417, 0.39261106,
#        0.41419077, 0.39325008, 0.42723882, 0.43865392, 0.42988536,
#        0.4319447 , 0.4109338 , 0.42120105, 0.42557865, 0.4331123 ,
#        0.3918525 , 0.41888875, 0.41125757, 0.41648427, 0.4250911 ,
#        0.4201781 , 0.43264708, 0.4403436 , 0.4565554 , 0.45208332,
#        0.470608  , 0.4594651 , 0.45006654, 0.45022905, 0.47618422,
#        0.4753882 , 0.47855702, 0.48551044, 0.47247684, 0.50039893,
#        0.5128445 , 0.5544996 , 0.50453156, 0.5247305 , 0.5206557 ,
#        0.52074516, 0.5476809 , 0.55736434, 0.5459157 , 0.5739564 ,
#        0.5764414 , 0.5842704 , 0.5912746 , 0.57511   , 0.58386314,
#        0.5559204 , 0.53347254, 0.5863669 , 0.59242   , 0.5999521 ,
#        0.61546457, 0.6336952 , 0.64055157, 0.6337635 , 0.6765012 ,
#        0.6586506 , 0.7051694 , 0.7098562 , 0.69502634, 0.7066663 ,
#        0.72423846, 0.70983994, 0.71741664, 0.69262445, 0.7045437 ,
#        0.7055744 , 0.6866983 , 0.6898068 , 0.68441993, 0.6950987 ,
#        0.6867692 , 0.69868284, 0.6961135 , 0.6923608 , 0.7316946 ,
#        0.723568  , 0.7180931 , 0.68786806, 0.722417  , 0.73288673,
#        0.7633827 , 0.7591747 , 0.6924763 , 0.704575  , 0.6855079 ,
#        0.6935025 , 0.68047965, 0.6533437 , 0.64043975, 0.6154607 ,
#        0.66505057, 0.67561877, 0.6837542 , 0.6556392 , 0.6243343 ,
#        0.6447678 , 0.6524673 , 0.674915  , 0.6643422 , 0.67090595,
#        0.68947834, 0.66311955, 0.68427765, 0.68256074, 0.6772769 ,
#        0.6482829 , 0.62440825, 0.63853496, 0.69653827, 0.68774354,
#        0.6976432 , 0.69561666, 0.71370035, 0.70430744, 0.700036  ,
#        0.6828432 , 0.67393786, 0.67523795, 0.6325425 , 0.6677168 ,
#        0.6524722 , 0.6929735 , 0.7178023 , 0.7035679 , 0.6866734 ,
#        0.6822081 , 0.6878453 , 0.68118596, 0.67450047, 0.6801755 ,
#        0.62141997, 0.6499079 , 0.6526219 , 0.6550874 , 0.7063356 ,
#        0.7046659 , 0.6913464 , 0.69311595, 0.7349109 , 0.742521  ,
#        0.73266125, 0.6883654 , 0.69915205, 0.7336021 , 0.7326851 ,
#        0.7740757 , 0.8022502 , 0.7896434 , 0.7781948 , 0.76823753,
#        0.75006396, 0.7584758 , 0.75223327, 0.74655855, 0.7000553 ,
#        0.7139404 , 0.6975592 , 0.6796361 , 0.71179086, 0.7025708 ,
#        0.7173536 , 0.70921576, 0.733132  , 0.7270466 , 0.7474434 ,
#        0.73090136, 0.6777421 , 0.69843155, 0.6960808 , 0.7182503 ,
#        0.72304934, 0.7146938 , 0.7478829 , 0.7993258 , 0.80848634,
#        0.8386027 , 0.8611011 , 0.8288429 , 0.79622877, 0.846608  ,
#        0.8451755 , 0.84370947, 0.8572063 , 0.83764255, 0.8604367 ,
#        0.87638646, 0.8596874 , 0.8552843 , 0.87698543, 0.85951585,
#        0.83912665, 0.86942536, 0.8722632 , 0.8352199 , 0.8670283 ,
#        0.86371464, 0.86061174, 0.86503756, 0.889138  , 0.86125225,
#        0.86197746, 0.87785804, 0.8745344 , 0.8913367 , 0.9098991 ,
#        0.88762134, 0.9072179 , 0.9221608 , 0.9107796 , 0.9109241 ,
#        0.98663217, 0.9898135 , 0.9962659 , 1.        , 0.966266  ,
#        0.98995364, 0.9775051 , 0.98162967, 0.99326336, 0.9758624 ,
#        0.9415099 , 0.9270517 , 0.954894  , 0.9441272 , 0.97939616,
#        0.9812748 , 0.9400163 , 0.9566557 , 0.9611039 , 0.9415392 ,
#        0.977886  , 0.9768759 , 0.96928865, 0.9490405 , 0.97600955,
#        0.8898764 , 0.9574427 , 0.9481614 , 0.8861701 , 0.90065014,
#        0.88642013, 0.9087041 , 0.9167534 , 0.91783065, 0.92374545,
#        0.8832642 , 0.93411386, 0.91093755, 0.9350916 , 0.9068376 ,
#        0.89074606, 0.9551608 , 0.9185406 , 0.8921256 , 0.8998866 ,
#        0.8884984 , 0.897054  , 0.8999947 , 0.9317674 , 0.9437584 ,
#        0.9213161 , 0.92270356, 0.8798251 , 0.84432244, 0.86834943,
#        0.89329505, 0.91675824, 0.90933657, 0.84824556, 0.87503695,
#        0.9088532 , 0.8831247 , 0.895918  , 0.88531345, 0.8908252 ,
#        0.89112794, 0.87415665, 0.89926976, 0.9098832 , 0.8997004 ,
#        0.95531416, 0.8912784 , 0.90358436, 0.8387875 , 0.8547874 ,
#        0.8448123 , 0.7875328 ], dtype=float32)

# %% [markdown]
# Based on the percentage of the validation set (perc), split the dataset in to training and validation, taking a percentage from each category list:

# %%
import math

perc = 0.1

X_train_raw_by_category = []
X_val_raw_by_category = []

for category in dataset_by_categories:
    tot_len = len(category)
    val_len = math.ceil(tot_len * perc)
    X_train_raw_by_category.append(category[ : tot_len-val_len])
    X_val_raw_by_category.append(category[tot_len-val_len : ])

for (train_category, val_category) in zip(X_train_raw_by_category, X_val_raw_by_category):
    print("Length of train: ", len(train_category), "- Length of val: ", len(val_category))
# Out:
# Length of train:  5155 - Length of val:  573
# Length of train:  9888 - Length of val:  1099
# Length of train:  9015 - Length of val:  1002
# Length of train:  9014 - Length of val:  1002
# Length of train:  9877 - Length of val:  1098
# Length of train:  249 - Length of val:  28

# %% [markdown]
# Unify all the lists into one single list (unify all categories):

# %%
X_train_raw = []
X_val_raw = []
train_categories = []
val_categories = []

for index, (train_category, val_category) in enumerate(zip(X_train_raw_by_category, X_val_raw_by_category)):
    for sequence in train_category:
        X_train_raw.append(sequence)
    for sequence in val_category:
        X_val_raw.append(sequence)

    for i in range(len(train_category)):
        train_categories.append(index_to_category[index])
    for i in range(len(val_category)):
        val_categories.append(index_to_category[index])

print("Length train: ", len(X_train_raw))
print("Length val: ", len(X_val_raw))
X_train_raw = np.array(X_train_raw)
X_val_raw = np.array(X_val_raw)
# Out:
# Length train:  43198
# Length val:  4802

# %% [markdown]
# # Data augmentation

# %% [markdown]
# Function to cut values under 0 or above 1 to 0 and 1 respectively:

# %%
def fix_normalization(seq):
    for i, el in enumerate(seq): #ensure not exceed range
        if el>1:
            seq[i] = 1
        elif el < -1:
            seq[i] = -1

    return seq

# %% [markdown]
# Add normal noise:

# %%
def normal_add(seq, sigma=0.1):
    return fix_normalization(np.add(seq, np.random.normal(loc=0., scale=sigma, size=len(seq))))

# %% [markdown]
# Multiply normal noise:

# %%
def normal_mul(seq, sigma=0.1):
    factors = np.random.normal(loc=1., scale=sigma, size=len(seq))
    return fix_normalization(np.multiply(seq, factors))

# %% [markdown]
# Create augmented time series:

# %%
import copy

perc_aug = 0

for i in range(int(len(X_train_raw) * perc_aug)):
    rand_seq_index = np.random.randint(len(X_train_raw))
    rand_aug = np.random.randint(2)
    if rand_aug == 0:
        aug_seq = normal_add(X_train_raw[rand_seq_index])
        X_train_raw.append(normal_add(X_train_raw[rand_seq_index]))
        train_categories.append(train_categories[rand_seq_index])
    elif rand_aug == 1:
        aug_seq = normal_mul(X_train_raw[rand_seq_index])
        X_train_raw.append(normal_mul(X_train_raw[rand_seq_index]))
        train_categories.append(train_categories[rand_seq_index])

plt.figure(figsize=(50, 15))
plt.plot(X_train_raw[-1], label='Time Series Data')
plt.title('Time Series Plot')
plt.xlabel('Index')
plt.ylabel('Data Values')
plt.legend()
plt.show()

# %%
X_train_raw = np.array(X_train_raw)
X_val_raw = np.array(X_val_raw)
train_categories = np.array(train_categories)
val_categories = np.array(val_categories)

# %% [markdown]
# Shuffle another time over the classes:

# %%
print(train_categories[0:10])
# Out:
# ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A']

# %%
indices = np.random.permutation(len(X_train_raw))
X_train_raw = X_train_raw[indices]
train_categories = train_categories[indices]

indices = np.random.permutation(len(X_val_raw))
X_val_raw = X_val_raw[indices]
val_categories = val_categories[indices]

# %%
print(train_categories[0:10])
# Out:
# ['C' 'E' 'A' 'B' 'E' 'E' 'C' 'B' 'B' 'A']

# %% [markdown]
# # Create windows

# %% [markdown]
# Build windows and targets:

# %%
def build_sequences(df, window, stride, telescope): #telescope is k, how many samples to predict
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy()
    temp_label = df.copy()
    padding_check = len(df)%window

    if(padding_check != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros(padding_len, dtype='float32')
        temp_df = np.concatenate((padding,df))
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride): #for each window, append values and also the values of telescope
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])
        # I get a series of chunk of a window. The label is a sequence of len telescope, which is what I should predict from the values in the window
        # Note that each chunk is 3 signals

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

def build_dataset_no_category(initial_dataset, window, stride, telescope):
    dataset = []
    labels = []
    dataset_of_sequence = []
    labels_of_sequence = []
    for sequence_input in initial_dataset:
        dataset_of_sequence, labels_of_sequence = build_sequences(sequence_input, window, stride, telescope)
        for sequence, label in zip(dataset_of_sequence, labels_of_sequence):
            dataset.append(sequence) #for dimension issue
            labels.append(label)

    dataset = np.array(dataset)
    labels = np.array(labels)

    return dataset, labels

# %%
X_train, y_train = build_dataset_no_category(X_train_raw, window=200, stride=20, telescope=9)
X_train = np.expand_dims(X_train, axis=-1)
y_train = np.expand_dims(y_train, axis=-1)
X_val, y_val = build_dataset_no_category(X_val_raw, window=200, stride=20, telescope=9)
X_val = np.expand_dims(X_val, axis=-1)
y_val = np.expand_dims(y_val, axis=-1)

# %%
print(X_train.shape)
# Out:
# (242040, 200, 1)

# %%
stop = 0
for i, sequence in enumerate(X_train):
    plt.figure(figsize=(50, 15))
    plt.plot(X_train[i].flatten(), label='Time Series Data')
    plt.title('Time Series Plot')
    plt.xlabel('Index')
    plt.ylabel('Data Values')
    plt.legend()
    plt.show()

    stop += 1
    if(stop==5): break

# %% [markdown]
# Show an example of input-target couple:

# %%
def inspect_multivariate(X, y, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(1, 1, sharex=True, figsize=(50, 15))
    axs.plot(np.arange(len(X[0,:])), X[idx,:])
    axs.scatter(np.arange(len(X[0,:]), len(X_train[0,:])+telescope), y[idx,:], color='orange')
    axs.set_title("Sequence with telescope")
    axs.set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate(X_train, y_train, telescope=9)

# %% [markdown]
# # Model

# %% [markdown]
# Define the parameters of the model:

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 512
epochs = 200
print("Input shape: ", input_shape, " => We will feed each chunk of this dimension one at a time.")
print("Output shape: ", output_shape, " => For each input chunk, we will predict an output chunk of this dimension")
# Out:
# Input shape:  (200, 1)  => We will feed each chunk of this dimension one at a time.
# Output shape:  (9, 1)  => For each input chunk, we will predict an output chunk of this dimension

# %% [markdown]
# Define the model:

# %%
def build_CONV_LSTM_model(input_shape, output_shape):
    # Ensure the input time steps are at least as many as the output time steps
    assert input_shape[0] >= output_shape[0], "For this exercise we want input time steps to be >= of output time steps"

    # Define the input layer with the specified shape
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    x = tfkl.Conv1D(32, 1, padding='same', activation='relu')(input_layer)
    x = tfkl.Bidirectional(tfkl.LSTM(16, return_sequences=True))(x)
    x = tfkl.Conv1D(32, 3, padding='same', activation='relu')(x)
    #x = tfkl.Conv1D(32, 3, padding='same', activation='relu')(x)
    x = tfkl.MaxPooling1D()(x)
    x = tfkl.Bidirectional(tfkl.LSTM(32, return_sequences=True))(x)

    x = tfkl.Conv1D(64, 3, padding='same', activation='relu')(x)
    #x = tfkl.Conv1D(64, 3, padding='same', activation='relu')(x)
    x = tfkl.MaxPooling1D()(x)
    x = tfkl.Conv1D(128, 3, padding='same', activation='relu')(x)
    #x = tfkl.Conv1D(128, 3, padding='same', activation='relu')(x)
    x = tfkl.MaxPooling1D()(x)
    x = tfkl.Bidirectional(tfkl.LSTM(64, return_sequences=True))(x)

    # Add a final Convolution layer to match the desired output shape
    #output_shape[1] = 3, the channels
    output_layer = tfkl.Conv1D(output_shape[1], 3, padding='same', name='output_layer')(x)

    # Calculate the size to crop from the output to match the output shape
    #A bidirectional lstm gives an output that has the same length as the input. A possible solution is
    #to crop the output
    crop_size = output_layer.shape[1] - output_shape[0]

    # Crop the output to the desired length
    output_layer = tfkl.Cropping1D((0, crop_size), name='cropping')(output_layer)

    # Construct the model by connecting input and output layers
    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='CONV_LSTM_model')

    # Compile the model with Mean Squared Error loss and Adam optimizer
    model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.Adam(weight_decay=5e-4), metrics=["mean_absolute_error"]) #RMSprop

    return model

# %%
model = build_CONV_LSTM_model(input_shape, output_shape)
model.summary()
tfk.utils.plot_model(model, expand_nested=True, show_shapes=True)
# Out:
# Model: "CONV_LSTM_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 200, 1)]          0
#
#  conv1d (Conv1D)             (None, 200, 32)           64
#
#  bidirectional (Bidirection  (None, 200, 32)           6272
#  al)
#
#  conv1d_1 (Conv1D)           (None, 200, 32)           3104
#
#  max_pooling1d (MaxPooling1  (None, 100, 32)           0
#  D)
#
#  bidirectional_1 (Bidirecti  (None, 100, 64)           16640
#  onal)
#
#  conv1d_2 (Conv1D)           (None, 100, 64)           12352
#
#  max_pooling1d_1 (MaxPoolin  (None, 50, 64)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 50, 128)           24704
#
#  max_pooling1d_2 (MaxPoolin  (None, 25, 128)           0
#  g1D)
#
#  bidirectional_2 (Bidirecti  (None, 25, 128)           98816
#  onal)
#
#  output_layer (Conv1D)       (None, 25, 1)             385
#
#  cropping (Cropping1D)       (None, 9, 1)              0
#
# =================================================================
# Total params: 162337 (634.13 KB)
# Trainable params: 162337 (634.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Train the model:

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    #validation_split=0.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=12, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=8, factor=0.1, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 473/473 [==============================] - 45s 56ms/step - loss: 0.0187 - mean_absolute_error: 0.0925 - val_loss: 0.0103 - val_mean_absolute_error: 0.0698 - lr: 0.0010
# Epoch 2/200
# 473/473 [==============================] - 24s 51ms/step - loss: 0.0097 - mean_absolute_error: 0.0663 - val_loss: 0.0098 - val_mean_absolute_error: 0.0670 - lr: 0.0010
# Epoch 3/200
# 473/473 [==============================] - 28s 58ms/step - loss: 0.0094 - mean_absolute_error: 0.0648 - val_loss: 0.0094 - val_mean_absolute_error: 0.0632 - lr: 0.0010
# Epoch 4/200
# 473/473 [==============================] - 22s 47ms/step - loss: 0.0089 - mean_absolute_error: 0.0626 - val_loss: 0.0093 - val_mean_absolute_error: 0.0650 - lr: 0.0010
# Epoch 5/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0086 - mean_absolute_error: 0.0615 - val_loss: 0.0086 - val_mean_absolute_error: 0.0609 - lr: 0.0010
# Epoch 6/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0082 - mean_absolute_error: 0.0596 - val_loss: 0.0083 - val_mean_absolute_error: 0.0606 - lr: 0.0010
# Epoch 7/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0077 - mean_absolute_error: 0.0578 - val_loss: 0.0077 - val_mean_absolute_error: 0.0579 - lr: 0.0010
# Epoch 8/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0075 - mean_absolute_error: 0.0567 - val_loss: 0.0076 - val_mean_absolute_error: 0.0575 - lr: 0.0010
# Epoch 9/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0074 - mean_absolute_error: 0.0563 - val_loss: 0.0074 - val_mean_absolute_error: 0.0567 - lr: 0.0010
# Epoch 10/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0072 - mean_absolute_error: 0.0556 - val_loss: 0.0072 - val_mean_absolute_error: 0.0551 - lr: 0.0010
# Epoch 11/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0071 - mean_absolute_error: 0.0552 - val_loss: 0.0072 - val_mean_absolute_error: 0.0551 - lr: 0.0010
# Epoch 12/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0070 - mean_absolute_error: 0.0546 - val_loss: 0.0070 - val_mean_absolute_error: 0.0551 - lr: 0.0010
# Epoch 13/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0069 - mean_absolute_error: 0.0540 - val_loss: 0.0071 - val_mean_absolute_error: 0.0553 - lr: 0.0010
# Epoch 14/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0068 - mean_absolute_error: 0.0537 - val_loss: 0.0069 - val_mean_absolute_error: 0.0542 - lr: 0.0010
# Epoch 15/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0067 - mean_absolute_error: 0.0531 - val_loss: 0.0068 - val_mean_absolute_error: 0.0527 - lr: 0.0010
# Epoch 16/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0066 - mean_absolute_error: 0.0528 - val_loss: 0.0067 - val_mean_absolute_error: 0.0532 - lr: 0.0010
# Epoch 17/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0065 - mean_absolute_error: 0.0524 - val_loss: 0.0066 - val_mean_absolute_error: 0.0525 - lr: 0.0010
# Epoch 18/200
# 473/473 [==============================] - 23s 48ms/step - loss: 0.0065 - mean_absolute_error: 0.0523 - val_loss: 0.0067 - val_mean_absolute_error: 0.0536 - lr: 0.0010
# Epoch 19/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0064 - mean_absolute_error: 0.0519 - val_loss: 0.0065 - val_mean_absolute_error: 0.0518 - lr: 0.0010
# Epoch 20/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0064 - mean_absolute_error: 0.0516 - val_loss: 0.0066 - val_mean_absolute_error: 0.0524 - lr: 0.0010
# Epoch 21/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0063 - mean_absolute_error: 0.0513 - val_loss: 0.0065 - val_mean_absolute_error: 0.0520 - lr: 0.0010
# Epoch 22/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0062 - mean_absolute_error: 0.0511 - val_loss: 0.0065 - val_mean_absolute_error: 0.0518 - lr: 0.0010
# Epoch 23/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0062 - mean_absolute_error: 0.0510 - val_loss: 0.0063 - val_mean_absolute_error: 0.0509 - lr: 0.0010
# Epoch 24/200
# 473/473 [==============================] - 22s 47ms/step - loss: 0.0061 - mean_absolute_error: 0.0508 - val_loss: 0.0063 - val_mean_absolute_error: 0.0514 - lr: 0.0010
# Epoch 25/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0061 - mean_absolute_error: 0.0503 - val_loss: 0.0063 - val_mean_absolute_error: 0.0513 - lr: 0.0010
# Epoch 26/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0060 - mean_absolute_error: 0.0500 - val_loss: 0.0061 - val_mean_absolute_error: 0.0502 - lr: 0.0010
# Epoch 27/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0059 - mean_absolute_error: 0.0497 - val_loss: 0.0061 - val_mean_absolute_error: 0.0503 - lr: 0.0010
# Epoch 28/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0059 - mean_absolute_error: 0.0495 - val_loss: 0.0063 - val_mean_absolute_error: 0.0517 - lr: 0.0010
# Epoch 29/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0059 - mean_absolute_error: 0.0496 - val_loss: 0.0064 - val_mean_absolute_error: 0.0519 - lr: 0.0010
# Epoch 30/200
# 473/473 [==============================] - 22s 47ms/step - loss: 0.0058 - mean_absolute_error: 0.0492 - val_loss: 0.0060 - val_mean_absolute_error: 0.0501 - lr: 0.0010
# Epoch 31/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0057 - mean_absolute_error: 0.0489 - val_loss: 0.0061 - val_mean_absolute_error: 0.0502 - lr: 0.0010
# Epoch 32/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0057 - mean_absolute_error: 0.0489 - val_loss: 0.0060 - val_mean_absolute_error: 0.0498 - lr: 0.0010
# Epoch 33/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0057 - mean_absolute_error: 0.0487 - val_loss: 0.0059 - val_mean_absolute_error: 0.0490 - lr: 0.0010
# Epoch 34/200
# 473/473 [==============================] - 22s 47ms/step - loss: 0.0056 - mean_absolute_error: 0.0484 - val_loss: 0.0060 - val_mean_absolute_error: 0.0497 - lr: 0.0010
# Epoch 35/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0056 - mean_absolute_error: 0.0483 - val_loss: 0.0060 - val_mean_absolute_error: 0.0498 - lr: 0.0010
# Epoch 36/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0055 - mean_absolute_error: 0.0480 - val_loss: 0.0059 - val_mean_absolute_error: 0.0500 - lr: 0.0010
# Epoch 37/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0055 - mean_absolute_error: 0.0482 - val_loss: 0.0058 - val_mean_absolute_error: 0.0490 - lr: 0.0010
# Epoch 38/200
# 473/473 [==============================] - 24s 50ms/step - loss: 0.0055 - mean_absolute_error: 0.0480 - val_loss: 0.0059 - val_mean_absolute_error: 0.0499 - lr: 0.0010
# Epoch 39/200
# 473/473 [==============================] - 25s 54ms/step - loss: 0.0054 - mean_absolute_error: 0.0476 - val_loss: 0.0059 - val_mean_absolute_error: 0.0490 - lr: 0.0010
# Epoch 40/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0054 - mean_absolute_error: 0.0475 - val_loss: 0.0058 - val_mean_absolute_error: 0.0487 - lr: 0.0010
# Epoch 41/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0054 - mean_absolute_error: 0.0474 - val_loss: 0.0059 - val_mean_absolute_error: 0.0498 - lr: 0.0010
# Epoch 42/200
# 473/473 [==============================] - 23s 48ms/step - loss: 0.0050 - mean_absolute_error: 0.0454 - val_loss: 0.0056 - val_mean_absolute_error: 0.0476 - lr: 1.0000e-04
# Epoch 43/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0050 - mean_absolute_error: 0.0452 - val_loss: 0.0056 - val_mean_absolute_error: 0.0479 - lr: 1.0000e-04
# Epoch 44/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0050 - mean_absolute_error: 0.0452 - val_loss: 0.0056 - val_mean_absolute_error: 0.0475 - lr: 1.0000e-04
# Epoch 45/200
# 473/473 [==============================] - 21s 44ms/step - loss: 0.0050 - mean_absolute_error: 0.0451 - val_loss: 0.0056 - val_mean_absolute_error: 0.0475 - lr: 1.0000e-04
# Epoch 46/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0050 - mean_absolute_error: 0.0451 - val_loss: 0.0056 - val_mean_absolute_error: 0.0476 - lr: 1.0000e-04
# Epoch 47/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0049 - mean_absolute_error: 0.0451 - val_loss: 0.0056 - val_mean_absolute_error: 0.0475 - lr: 1.0000e-04
# Epoch 48/200
# 473/473 [==============================] - 23s 48ms/step - loss: 0.0049 - mean_absolute_error: 0.0450 - val_loss: 0.0056 - val_mean_absolute_error: 0.0477 - lr: 1.0000e-04
# Epoch 49/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0049 - mean_absolute_error: 0.0450 - val_loss: 0.0056 - val_mean_absolute_error: 0.0475 - lr: 1.0000e-04
# Epoch 50/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0049 - mean_absolute_error: 0.0450 - val_loss: 0.0056 - val_mean_absolute_error: 0.0475 - lr: 1.0000e-04
# Epoch 51/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0049 - mean_absolute_error: 0.0447 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 52/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0473 - lr: 1.0000e-05
# Epoch 53/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 54/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 55/200
# 473/473 [==============================] - 22s 47ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 56/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 57/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 58/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 59/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 60/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0474 - lr: 1.0000e-05
# Epoch 61/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0473 - lr: 1.0000e-05
# Epoch 62/200
# 473/473 [==============================] - 21s 45ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0473 - lr: 1.0000e-05
# Epoch 63/200
# 473/473 [==============================] - 23s 49ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0473 - lr: 1.0000e-05
# Epoch 64/200
# 473/473 [==============================] - 22s 46ms/step - loss: 0.0048 - mean_absolute_error: 0.0446 - val_loss: 0.0056 - val_mean_absolute_error: 0.0473 - lr: 1.0000e-05

# %% [markdown]
# Plot training and validation loss over time:

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# Save the model:

# %%
model.save('LSTM')
